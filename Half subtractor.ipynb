# %%
import qiskit
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi
from qiskit import *
from qiskit.visualization import plot_histogram
import numpy as np
# %matplotlib inline
def halfsub(x,y):
    qc = QuantumCircuit(3, 2) 
    if x==1:
        qc.x(0)
    if y==1:
        qc.x(1)
    qc.cx(0,1)
    qc.measure(1, 0)
    qc.x(0)
    qc.ccx(0,1,2)
    qc.measure(2, 1)
    simulator = Aer.get_backend('qasm_simulator')
    result = execute(qc, backend=simulator).result()
    return plot_histogram(result.get_counts(qc))

# %%
 halfsub(0,0)

# %%
 halfsub(0,1)

# %%
halfsub(1,0)

# %%
halfsub(1,1)

# %%
qc = QuantumCircuit(3, 2) 
qc.cx(0,1)
qc.measure(1, 0)
qc.x(0)
qc.ccx(0,1,2)
qc.measure(2, 1)
qc.draw(output='mpl')

# %%
IBMQ.load_account()
provider = IBMQ.get_provider('ibm-q')
# Out:
# ibmqfactory.load_account:WARNING:2021-03-12 10:41:21,123: Credentials are already in use. The existing account in the session will be replaced.

# %%
def HALFSUB(x,y):
    qc = QuantumCircuit(3, 2) 
    if x==1:
        qc.x(0)
    if y==1:
        qc.x(1)
    qc.cx(0,1)
    qc.measure(1, 0)
    qc.x(0)
    qc.ccx(0,1,2)
    qc.measure(2, 1)
    qcomp = provider.get_backend('ibmq_16_melbourne')
    job = execute(qc,backend=qcomp)
    from qiskit.tools.monitor import job_monitor
    job_monitor(job)
    result= job.result()
    return plot_histogram(result.get_counts(qc))

# %%
HALFSUB(0,0)
# Out:
# Job Status: job is actively running

# %%
HALFSUB(0,1)
# Out:
# Job Status: job has successfully run

# %%
HALFSUB(1,0)
# Out:
# Job Status: job has successfully run

# %%
HALFSUB(1,1)
# Out:
# Job Status: job has successfully run
